# %%
import pandas as pd
import missingno as msno
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from sklearn.ensemble import RandomForestClassifier 
from sklearn.linear_model import SGDClassifier
from sklearn.model_selection import train_test_split
from category_encoders import TargetEncoder
from sklearn.metrics import roc_auc_score
from sklearn.metrics import accuracy_score
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.experimental import enable_halving_search_cv
from sklearn.model_selection import HalvingGridSearchCV
import pickle

# %%
df = pd.read_csv('D:/НЕудалять PANDAS И ПРОЧЕЕ/ФИНАЛЬНЫЙ ПРОЕКТ/ga_hits-001.csv')
df1 = pd.read_csv('D:/НЕудалять PANDAS И ПРОЧЕЕ/ФИНАЛЬНЫЙ ПРОЕКТ/ga_sessions.csv')
# Out:
# C:\Users\Тарас\AppData\Local\Temp\ipykernel_10688\4011473579.py:2: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   df1 = pd.read_csv('D:/НЕудалять PANDAS И ПРОЧЕЕ/ФИНАЛЬНЫЙ ПРОЕКТ/ga_sessions.csv')

# %%
df.head()
# Out:
#                                   session_id    hit_date  hit_time  \
# 0  5639623078712724064.1640254056.1640254056  2021-12-23  597864.0
# 1  7750352294969115059.1640271109.1640271109  2021-12-23  597331.0
# 2   885342191847998240.1640235807.1640235807  2021-12-23  796252.0
# 3   142526202120934167.1640211014.1640211014  2021-12-23  934292.0
# 4  3450086108837475701.1640265078.1640265078  2021-12-23  768741.0
#
#    hit_number hit_type hit_referer  \
# 0          30    event         NaN
# 1          41    event         NaN
# 2          49    event         NaN
# 3          46    event         NaN
# 4          79    event         NaN
#
#                                        hit_page_path event_category  \
# 0  sberauto.com/cars?utm_source_initial=google&ut...           quiz
# 1  sberauto.com/cars/fiat?city=1&city=18&rental_c...           quiz
# 2  sberauto.com/cars/all/volkswagen/polo/e994838f...           quiz
# 3  sberauto.com/cars?utm_source_initial=yandex&ut...           quiz
# 4  sberauto.com/cars/all/mercedes-benz/cla-klasse...           quiz
#
#   event_action event_label  event_value
# 0    quiz_show         NaN          NaN
# 1    quiz_show         NaN          NaN
# 2    quiz_show         NaN          NaN
# 3    quiz_show         NaN          NaN
# 4    quiz_show         NaN          NaN

# %% [markdown]
# **DataPreparation**

# %%
df['event_value'] = (df['event_action'].str.startswith('sub').astype(bool)).astype(int)

# %%
df1 = df1.merge(df[['session_id', 'event_value']], on = 'session_id', how = 'inner')

# %%
df1 = df1.drop_duplicates(subset = ['session_id'])

# %%
df1.head()
# Out:
#                                    session_id          client_id  visit_date  \
# 0   9055434745589932991.1637753792.1637753792  2108382700.163776  2021-11-24
# 2    905544597018549464.1636867290.1636867290   210838531.163687  2021-11-14
# 3   9055446045651783499.1640648526.1640648526  2108385331.164065  2021-12-28
# 19  9055447046360770272.1622255328.1622255328  2108385564.162225  2021-05-29
# 22  9055447046360770272.1622255345.1622255345  2108385564.162225  2021-05-29
#
#    visit_time  visit_number            utm_source utm_medium  \
# 0    14:36:32             1  ZpYIoDJMcFzVoPFsHGJL     banner
# 2    08:21:30             1  MvfHsxITijuriZxsqZqt        cpm
# 3    02:42:06             1  ZpYIoDJMcFzVoPFsHGJL     banner
# 19   05:00:00             1  kjsLglQLzykiRbcDiGcD        cpc
# 22   05:00:00             2  kjsLglQLzykiRbcDiGcD        cpc
#
#             utm_campaign         utm_adcontent           utm_keyword  \
# 0   LEoPHuyFvzoNfnzGgfcd  vCIpmpaGBnIQhyYNkXqp  puhZPIYqKXeFPaUviSjo
# 2   FTjNLDyTrXaWYgZymFkV  xhoenQgDQsgfEPYNPwKO  IGUCNvHlhfHpROGclCit
# 3   LEoPHuyFvzoNfnzGgfcd  vCIpmpaGBnIQhyYNkXqp  puhZPIYqKXeFPaUviSjo
# 19                   NaN  NOBKLgtuvqYWkXQHeYWM                   NaN
# 22                   NaN                   NaN                   NaN
#
#    device_category device_os device_brand device_model  \
# 0           mobile   Android       Huawei          NaN
# 2           mobile   Android      Samsung          NaN
# 3           mobile   Android       Huawei          NaN
# 19          mobile       NaN       Xiaomi          NaN
# 22          mobile       NaN       Xiaomi          NaN
#
#    device_screen_resolution    device_browser geo_country     geo_city  \
# 0                   360x720            Chrome      Russia     Zlatoust
# 2                   385x854  Samsung Internet      Russia       Moscow
# 3                   360x720            Chrome      Russia  Krasnoyarsk
# 19                  393x786            Chrome      Russia       Moscow
# 22                  393x786            Chrome      Russia       Moscow
#
#     event_value
# 0             1
# 2             1
# 3             0
# 19            1
# 22            0

# %%
df1[df1.duplicated()]
# Out:
# Empty DataFrame
# Columns: [session_id, client_id, visit_date, visit_time, visit_number, utm_source, utm_medium, utm_campaign, utm_adcontent, utm_keyword, device_category, device_os, device_brand, device_model, device_screen_resolution, device_browser, geo_country, geo_city, event_value]
# Index: []

# %%
def nan_med(df, col):
    st_med = df[col].median()
    df[col] = df[col].fillna(st_med)
    return df

# %%
def nan_mod(df, col):
    st_mod = df[col].mode()[0]
    df[col] = df[col].fillna(st_mod)
    return df

# %%
nan_mod(df1, 'utm_source')
nan_mod(df1, 'utm_campaign')
nan_mod(df1, 'utm_medium')
nan_mod(df1, 'device_brand')
nan_mod(df1, 'utm_keyword')
nan_mod(df1, 'utm_adcontent')
# Out:
#                                          session_id          client_id  \
# 0         9055434745589932991.1637753792.1637753792  2108382700.163776
# 2          905544597018549464.1636867290.1636867290   210838531.163687
# 3         9055446045651783499.1640648526.1640648526  2108385331.164065
# 19        9055447046360770272.1622255328.1622255328  2108385564.162225
# 22        9055447046360770272.1622255345.1622255345  2108385564.162225
# ...                                             ...                ...
# 15685150  9055415581448263752.1640159305.1640159305  2108378238.164016
# 15685152  9055421130527858185.1622007305.1622007305  2108379530.162201
# 15685163  9055422955903931195.1636979515.1636979515  2108379955.163697
# 15685204   905543020766873816.1638189404.1638189404   210838164.163819
# 15685206  9055430416266113553.1640968742.1640968742  2108381692.164097
#
#           visit_date visit_time  visit_number            utm_source  \
# 0         2021-11-24   14:36:32             1  ZpYIoDJMcFzVoPFsHGJL
# 2         2021-11-14   08:21:30             1  MvfHsxITijuriZxsqZqt
# 3         2021-12-28   02:42:06             1  ZpYIoDJMcFzVoPFsHGJL
# 19        2021-05-29   05:00:00             1  kjsLglQLzykiRbcDiGcD
# 22        2021-05-29   05:00:00             2  kjsLglQLzykiRbcDiGcD
# ...              ...        ...           ...                   ...
# 15685150  2021-12-22   10:48:25             1  BHcvLfOaCWvWTykYqHVe
# 15685152  2021-05-26   08:00:00             1  fDLlAcSmythWSCVMvqvL
# 15685163  2021-11-15   15:31:55             1  fDLlAcSmythWSCVMvqvL
# 15685204  2021-11-29   15:36:44             1  ZpYIoDJMcFzVoPFsHGJL
# 15685206  2021-12-31   19:39:02             1  fgymSoTvjKPEgaIJqsiH
#
#          utm_medium          utm_campaign         utm_adcontent  \
# 0            banner  LEoPHuyFvzoNfnzGgfcd  vCIpmpaGBnIQhyYNkXqp
# 2               cpm  FTjNLDyTrXaWYgZymFkV  xhoenQgDQsgfEPYNPwKO
# 3            banner  LEoPHuyFvzoNfnzGgfcd  vCIpmpaGBnIQhyYNkXqp
# 19              cpc  LTuZkdKfxRGVceoWkVyg  NOBKLgtuvqYWkXQHeYWM
# 22              cpc  LTuZkdKfxRGVceoWkVyg  JNHcPlZPxEMWDnRiyoBf
# ...             ...                   ...                   ...
# 15685150        cpc  LTuZkdKfxRGVceoWkVyg  JNHcPlZPxEMWDnRiyoBf
# 15685152     (none)  LTuZkdKfxRGVceoWkVyg  JNHcPlZPxEMWDnRiyoBf
# 15685163     (none)  LTuZkdKfxRGVceoWkVyg  JNHcPlZPxEMWDnRiyoBf
# 15685204     banner  LEoPHuyFvzoNfnzGgfcd  JNHcPlZPxEMWDnRiyoBf
# 15685206        cpm  FTjNLDyTrXaWYgZymFkV  yYdBRbPmBMUZHXwqGxNx
#
#                    utm_keyword device_category device_os device_brand  \
# 0         puhZPIYqKXeFPaUviSjo          mobile   Android       Huawei
# 2         IGUCNvHlhfHpROGclCit          mobile   Android      Samsung
# 3         puhZPIYqKXeFPaUviSjo          mobile   Android       Huawei
# 19        puhZPIYqKXeFPaUviSjo          mobile       NaN       Xiaomi
# 22        puhZPIYqKXeFPaUviSjo          mobile       NaN       Xiaomi
# ...                        ...             ...       ...          ...
# 15685150  VlqBmecIOXWjCWUmQkLd         desktop   Windows        Apple
# 15685152  puhZPIYqKXeFPaUviSjo          mobile       NaN        Apple
# 15685163  puhZPIYqKXeFPaUviSjo          mobile       iOS        Apple
# 15685204  puhZPIYqKXeFPaUviSjo          mobile   Android       Xiaomi
# 15685206  oKjXDUsycmahkgMhGdAR         desktop     Linux        Apple
#
#          device_model device_screen_resolution    device_browser geo_country  \
# 0                 NaN                  360x720            Chrome      Russia
# 2                 NaN                  385x854  Samsung Internet      Russia
# 3                 NaN                  360x720            Chrome      Russia
# 19                NaN                  393x786            Chrome      Russia
# 22                NaN                  393x786            Chrome      Russia
# ...               ...                      ...               ...         ...
# 15685150          NaN                1920x1080            Chrome      Russia
# 15685152          NaN                  390x844            Safari      Russia
# 15685163          NaN                  375x667            Safari      Russia
# 15685204          NaN                  393x851            Chrome      Russia
# 15685206          NaN                 1366x768            Chrome      Russia
#
#              geo_city  event_value
# 0            Zlatoust            1
# 2              Moscow            1
# 3         Krasnoyarsk            0
# 19             Moscow            1
# 22             Moscow            0
# ...               ...          ...
# 15685150       Moscow            1
# 15685152    Stavropol            1
# 15685163       Moscow            0
# 15685204  Chelyabinsk            1
# 15685206       Moscow            0
#
# [1732266 rows x 19 columns]

# %%
group_med_1 = df1.groupby(['device_brand', 'device_category'])['device_model'].agg(lambda x: x.mode()[0] if len(x.mode()) > 0 else None)
mode_device = df1['device_model'].mode()[0] 
df1['device_model'] = df1['device_model'].fillna(df1[['device_brand', 'device_category']].apply(tuple,axis = 1).map(group_med_1)).fillna(mode_device)

# %%
med_os = df1.groupby(['device_brand', 'device_model'])['device_os'].agg(lambda x: x.mode()[0] if len(x.mode()) > 0 else None)
mode_os = df1['device_os'].mode()[0]
df1['device_os'] = df1['device_os'].fillna(df1[['device_brand', 'device_model']].apply(tuple, axis = 1).map(med_os)).fillna(mode_os)

# %%
msno.bar(df1)
# Out:
# <Axes: >

# %%
feauters = ['utm_source', 'utm_medium', 'utm_campaign', 'utm_adcontent', 'utm_keyword',	
    'device_category', 'device_os',	'device_brand',	'device_model',	
    'device_screen_resolution',	'device_browser', 'geo_country', 'geo_city']

# %%
encoder = TargetEncoder(smoothing = 10)
x1 = df1[feauters]
y1 = df1['event_value']
x1_train, x1_test, y1_train, y1_test = train_test_split(x1, y1, test_size = 0.2, random_state = 42)
x_analyse_enc = encoder.fit_transform(x1_train, y1_train)
x_analyse_enc['target'] = df1['event_value']

# %% [markdown]
# **Visualization**

# %%
correl = x_analyse_enc.corr()['target'].drop('target').sort_values(ascending=False)
plt.figure(figsize=(10, 6))
sns.heatmap(correl.to_frame(), 
            annot=True, 
            cmap='vlag', 
            center=0,
            fmt='.3f',
            linewidths=0.5)
plt.title('Корреляция признаков с целевой переменной (классификация)', fontsize=14)
plt.show()

# %%
sns.set_theme(style="whitegrid")
plt.figure(figsize=(15,9))
sns.countplot(data = df1, x = 'device_os')
plt.title('Распределение по ОС')
plt.xlabel('Тип ОС')
plt.ylabel('Количество')
plt.show()

# %%
plt.figure(figsize=(9,5))
sns.countplot(data = df1, x = 'device_category')
plt.title('Распределение по брендам')
plt.xlabel('Устройство')
plt.ylabel('Количество')
plt.show()

# %% [markdown]
# **Modeling**

# %%
x = df1[feauters]
y = df1['event_value']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 42)

# %%
x_train_enc = encoder.fit_transform(x_train, y_train)

# %%
x_enc_test = encoder.transform(x_test)

# %%
model_rf = RandomForestClassifier (
    n_estimators=100,
    bootstrap=True,       
    max_samples=0.1,       
    random_state=42,
    n_jobs=-1)
logreg_sgd = SGDClassifier(
    loss='log_loss',  
    max_iter=20,      
    learning_rate='optimal',
    random_state=42,
    n_jobs=-1)

# %%
model_rf.fit(x_train_enc, y_train)
logreg_sgd.fit(x_train_enc, y_train)
# Out:
# SGDClassifier(loss='log_loss', max_iter=20, n_jobs=-1, random_state=42)

# %%
pred_rf = model_rf.predict(x_enc_test)
pred_log = logreg_sgd.predict(x_enc_test)

# %%
accuracy_rf = accuracy_score(y_test, pred_rf)
accuracy_log = accuracy_score(y_test, pred_log)

# %%
print(f'{accuracy_rf:.4f}')
# Out:
# 0.7049

# %%
print(f'{accuracy_log:.4f}')
# Out:
# 0.6832

# %%
y_pred_proba_rf = model_rf.predict_proba(x_enc_test)[:, 1]
auc_rf = roc_auc_score(y_test, y_pred_proba_rf)
y_pred_proba_log = logreg_sgd.predict_proba(x_enc_test)[:, 1]
auc_log = roc_auc_score(y_test, y_pred_proba_log)

# %%
print(f"AUC-ROC-RF: {auc_rf:.4f}, AUC-ROC-LOG: {auc_log:.4f}")
# Out:
# AUC-ROC-RF: 0.7783, AUC-ROC-LOG: 0.7490

# %%
param_grid = {
    'max_depth': [5, 10, 15],
    'min_samples_split': [2, 5, 10]
}

# %%
rf_boost = RandomForestClassifier ()

# %%
x_sample, y_sample = x_train_enc[:100000], y_train[:100000]

# %%
hg = HalvingGridSearchCV(estimator = rf_boost, param_grid = param_grid, resource = 'n_estimators', 
                                           max_resources = 300, min_resources = 100, factor = 2, cv = 3, n_jobs=-1, random_state = 42)

# %%
hg.fit(x_sample, y_sample)
# Out:
# HalvingGridSearchCV(cv=3, estimator=RandomForestClassifier(), factor=2,
#                     max_resources=300, min_resources=100, n_jobs=-1,
#                     param_grid={'max_depth': [5, 10, 15],
#                                 'min_samples_split': [2, 5, 10]},
#                     random_state=42, resource='n_estimators')

# %%
model_rf_boost = RandomForestClassifier (
    n_estimators=200,
    max_depth = 15,
    bootstrap=True,       
    max_samples=0.1,       
    random_state=42,
    min_samples_split= 5,	
    n_jobs=-1)

# %%
model_rf_boost.fit(x_train_enc, y_train)
# Out:
# RandomForestClassifier(max_depth=15, max_samples=0.1, min_samples_split=5,
#                        n_estimators=200, n_jobs=-1, random_state=42)

# %%
pred_boost = model_rf_boost.predict(x_enc_test)

# %%
accuracy_boost = accuracy_score(y_test, pred_boost)
accuracy_boost
# Out:
# 0.7058137588251254

# %%
proba_boost = model_rf_boost.predict_proba(x_enc_test)[:, 1]

# %%
roc_boost = roc_auc_score(y_test, proba_boost)

# %%
print(f"AUC-ROC-RF: {roc_boost:.4f}")
# Out:
# AUC-ROC-RF: 0.7796

# %%
with open('model.pkl', 'wb') as f:
    pickle.dump(model_rf_boost, f)
